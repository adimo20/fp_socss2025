# %% [markdown]
# # Unteruschung der Extraktionsqualität

# %%
import os
import pandas as pd
from ddbapi import zp_pages

places = ["Köln"]

outdir = "data"
if not os.path.isdir(outdir):
    os.mkdir(outdir)
#Save all the datasets individually - so we have a checkpoint for the org. data
df_list = []
for place in places:
    df = zp_pages(
        publication_date='[1850-01-01T12:00:00Z TO 1980-12-31T12:00:00Z]', 
        place_of_distribution=place, 
        plainpagefulltext=["Heiratsgesuch"]
        )
    
    df_list.append(df)

df_final = pd.concat(df_list)
df_final.to_pickle("ddbapi_data_koeln.pkl")
# Out:
# https://api.deutsche-digitale-bibliothek.de/search/index/newspaper-issues/select?rows=1000&sort=id+ASC&q=type%3Apage+AND+publication_date%3A%22%5B1850-01-01T12%3A00%3A00Z%5C+TO%5C+1980-12-31T12%3A00%3A00Z%5D%22+AND+place_of_distribution%3A%22K%C3%B6ln%22+AND+%28plainpagefulltext%3AHeiratsgesuch%29&cursorMark=%2A
# Getting 1000 of 2696
# Getting 2000 of 2696
# Getting 2696 of 2696
# Got 2696 items.

# %%
import pandas as pd

df_final = pd.read_pickle("ddbapi_data_koeln.pkl")

# %%
from scripts.information_extractor_lib import InformationExtractor

information_extractor = InformationExtractor(df=df_final, page_id_colname="page_id", text_colname="plainpagefulltext", output_filename="out_df.csv")
information_extractor.save_one_result_per_row = False
ergebnis_df = information_extractor.extract_data_loop(max_n = 10)
print(ergebnis_df)
# Out:
#                                              page_id  \
# 0  22KVFOV36KTZS67POXRNU5DJKD4XYSPI-ALTO1934911_D...
# 1  23GSP3TO42E3USTLALB2X5EHUMBSEOWM-ALTO8960309_D...
# 2  23JRMGNQTVLEGWUXLZ6D34KX4C4GCJNH-ALTO7691058_D...
# 3  245BHDGA6W5OOYPCWEGLHABY6LM7YNXP-ALTO7758526_D...
# 4  24KXQUATL73II54JILODDITR7CKGE7L4-ALTO2320495_D...
# 5  2537G7CWASBPS3RB4D6HOOJCTI3X6P24-ALTO372289_DD...
# 6  254IA3LVBUBODIO6NDVHDOJOA654B5KT-ALTO10118878_...
# 7  257JWTXYMDZQIF4DFV67FVD6FCP7MNN3-ALTO10158655_...
# 8  25EFYTTDJ6ZZXEVF33JRQTD6I3UXILDC-ALTO8101159_D...
# 9  25FPH6FZUIBNZJYXMXXDMC7CKZH6Q7E6-ALTO8702702_D...
#
#                                                 text              time
# 0  [Suche für meine Tochter , 18 Jahre , Stelle a...  2025-06-27_11_22
# 1  [Tehal nach Brükcnes . Gewissenhafter deutsche...  2025-06-27_11_22
# 2  [Suche f . meine Nichte ohne d . Wissen S tein...  2025-06-27_11_22
# 3  [Energischer Reisender . , 27 . , sucht Engage...  2025-06-27_11_22
# 4  [Das kleine „Heiratsgesuch“ in der illustriert...  2025-06-27_11_22
# 5  [Heiratsgesuch . Witwer , kath . , 36 . , 2 Ki...  2025-06-27_11_22
# 6  [Netles Heiratsgesuch . Junggeselle vom Lande ...  2025-06-27_11_22
# 7  [Heirats - Auskunfte ber H Geschwister ) Frebe...  2025-06-27_11_22
# 8  [Reelles Heiratsgesuch ähr Junger verm . B . E...  2025-06-27_11_22
# 9  [Heirat .\nFür zwei junge Damen chlerung , Töc...  2025-06-27_11_22

# %%
information_extractor.save_one_result_per_row
# Out:
# True

# %% [markdown]
# # Unnesting the Data - because per row multiple results are saved

# %%
def unnest_data(ergebnis_df:pd.DataFrame) -> pd.DataFrame:
    erg_list = []
    for i in range(len(ergebnis_df)):
        temp_list = []
        row = ergebnis_df.iloc[i,:]
        for t in row["text"]:
            temp_list.append(t)
        n = len(temp_list)
        df_temp = pd.DataFrame(data={"page_id":[row["page_id"]]*n, "text":temp_list,"time":[row["time"]]*n})
        erg_list.append(df_temp)
    df_unnested = pd.concat(erg_list)
    return df_unnested.reset_index().filter(["page_id", "text", "time"])

# %%
full_data = unnest_data(ergebnis_df)

# %%
full_data
# Out:
#                                               page_id  \
# 0   22KVFOV36KTZS67POXRNU5DJKD4XYSPI-ALTO1934911_D...
#
# 29  Heirat Frl . , 29 . , aus g . Fam . , kath . ,...  2025-06-27_11_22
# 30  Netles Heiratsgesuch . Junggeselle vom Lande ,...  2025-06-27_11_22
# 31  Heirats - Auskunfte ber H Geschwister ) Freben...  2025-06-27_11_22
# 32  Heiratsgesuch . ver g . Kfr Sbnss Kreis geoun ...  2025-06-27_11_22
# 33  Neigungsheirat 1765 groc , 9 ann b gen ,  v : ...  2025-06-27_11_22
# 34  int . Mr jug Shamaft . 935 Die Zrnech wais Bei...  2025-06-27_11_22
# 35  Rheinländerin 22 . , aus gut . Famile , mit Ba...  2025-06-27_11_22
# 36  Für m . Nichte 1 . , reiz . Mädch . v . kr Na ...  2025-06-27_11_22
# 37  Für meine Freundin alse 1ieb beini , be Gstäti...  2025-06-27_11_22
# 38  Reelles Heiratsgesuch ähr Junger verm . B . Ei...  2025-06-27_11_22
# 39  Herzenswunsch . Geb . Dame , temperamentv . in...  2025-06-27_11_22
# 40  ine Fabrikanten - Witwe , * in den 40er Jahren...  2025-06-27_11_22
# 41  Heirat .\nFür zwei junge Damen chlerung , Töch...  2025-06-27_11_22
# 42  Mariage . Wohlhbd . Fabrikbes . , jung . , an ...  2025-06-27_11_22
# 43  Di1 uche für einen Verwandt Architekt , Mitinh...  2025-06-27_11_22
# 44  Streng rel . suche für meinen Freund Witwer , ...  2025-06-27_11_22
# 45  Heiratsgesuch . Intelligenter Herr , stattl . ...  2025-06-27_11_22

# %%
unique_page_ids = full_data[full_data.filter(["page_id"]).duplicated() == False]["page_id"].to_list()

# %% [markdown]
# ## Berechnung der Accuracy der Informationsextraction
#
# Es wird für jeden Full-Text für Berechnet ob die entnommenen Kontaktanzeigen 1:1 genau so im Volltext enthalten sind wie sie von der GeminiAPI entnommen werden. Es wird ein über die Anzahl der entnommenen Anzeigen gewichteter Mittelwert der Accuracy berechnet.

# %%
n = len(full_data)
total_extracted = 0
weighted_perfect_extraction_ratio = 0
for i in range(len(unique_page_ids)):

    curr_full_text = df_final[df_final.page_id == unique_page_ids[i]].plainpagefulltext.tolist()[0]
    exctracted = full_data[full_data.page_id == unique_page_ids[i]].text.tolist()
    perfect_extraction_ratio = sum([e in curr_full_text for e in exctracted])/len(exctracted)
    total_extracted += sum([e in curr_full_text for e in exctracted])
    weighted_perfect_extraction_ratio += perfect_extraction_ratio*(len(exctracted)/n)



    #print(f"Extraction Ratio {perfect_extraction_ratio}, Len of extracted {len(exctracted)} ")

print(f"Total perfect_extraction_ratio weighted {weighted_perfect_extraction_ratio}")
print(f"Total extraction rate: {total_extracted/n}")
# Out:
# Total perfect_extraction_ratio weighted 0.8043478260869564
# Total extraction rate: 0.8043478260869565

# %% [markdown]
# # Untersuchen ob es kleinere Fehler gibt, die nicht den Sinn/Struktur verändern.
#
# Prüfen ob der String mit einer annähernden Gleichheit im Originaltext vorhanden ist.

# %%
df_red = df_final.filter(["page_id", "plainpagefulltext"])

dat_joined = pd.merge(full_data, df_red, on="page_id", how="left")
dat_joined
# Out:
#                                               page_id  \
# 0   22KVFOV36KTZS67POXRNU5DJKD4XYSPI-ALTO1934911_D...
# 1   22KVFOV36KTZS67POXRNU5DJKD4XYSPI-ALTO1934911_D...
# 2   22KVFOV36KTZS67POXRNU5DJKD4XYSPI-ALTO1934911_D...
# 3   22KVFOV36KTZS67POXRNU5DJKD4XYSPI-ALTO1934911_D...
#
Mittwoch , 4 . Juni in den Ver . Staten aufero...
# 5   Mittwoch , 4 . Juni in den Ver . Staten aufero...
# 6   Mittwoch , 4 . Juni in den Ver . Staten aufero...
# 7   Mittwoch , 4 . Juni in den Ver . Staten aufero...
# 8   Mittwoch , 4 . Juni in den Ver . Staten aufero...
# 10  Mittwoch , 4 . Juni in den Ver . Staten aufero...
# 11  Orzug altbewährten MAGGI WURZE 1 . Feinstes Ar...
# 12  Orzug altbewährten MAGGI WURZE 1 . Feinstes Ar...
# 13  Orzug altbewährten MAGGI WURZE 1 . Feinstes Ar...
# 14  Orzug altbewährten MAGGI WURZE 1 . Feinstes Ar...
# 15  Orzug altbewährten MAGGI WURZE 1 . Feinstes Ar...
# 16  Soennecken - Federn Das beste , was die Schrei...
# 17  Soennecken - Federn Das beste , was die Schrei...
# 18  Soennecken - Federn Das beste , was die Schrei...
# 19  Soennecken - Federn Das beste , was die Schrei...
# 20  Soennecken - Federn Das beste , was die Schrei...
# 21  Soennecken - Federn Das beste , was die Schrei...
# 24  Soennecken - Federn Das beste , was die Schrei...
# 25  Soennecken - Federn Das beste , was die Schrei...
# 27  Seite 14 . Prachtv . Eichen m . 2,10 m Büjett ...
# 28  Seite 14 . Prachtv . Eichen m . 2,10 m Büjett ...
# 29  Seite 14 . Prachtv . Eichen m . 2,10 m Büjett ...
# 31  22 . SEPTEMBER 1929 DIE LITERATUR AUS VERSCHIE...
# 33  22 . SEPTEMBER 1929 DIE LITERATUR AUS VERSCHIE...
# 34  22 . SEPTEMBER 1929 DIE LITERATUR AUS VERSCHIE...
# 35  22 . SEPTEMBER 1929 DIE LITERATUR AUS VERSCHIE...
# 36  22 . SEPTEMBER 1929 DIE LITERATUR AUS VERSCHIE...
# 37  22 . SEPTEMBER 1929 DIE LITERATUR AUS VERSCHIE...
# 38  Todes - Anzeige . Nach Gottes unerforschlichem...
# 39  Todes - Anzeige . Nach Gottes unerforschlichem...
# 40  Todes - Anzeige . Nach Gottes unerforschlichem...
# 42  fufschhe Allerersten Ranges , Inmitten eines e...
# 44  fufschhe Allerersten Ranges , Inmitten eines e...
# 45  fufschhe Allerersten Ranges , Inmitten eines e...

# %% [markdown]
# Laufen lassen des Strings über den Ausgangstext und extrahieren der Sequencen die eine Stringsimiliarity (Levenstein Distance) von größer 0.98 haben um zu schauen, ob wir approximativ die gleichen Texte haben.

# %%
dat_joined.to_pickle("dat_joined.pkl")

# %%
from rapidfuzz import fuzz

def find_similiar_sequence(dst_doc, source_doc, threshold:float):

    n = len(dst_doc)
    n_src = len(source_doc)
    i = 0

    best_match_list = []
    best_ratio_list = []
    while n < n_src:
        stringsim = fuzz.ratio(dst_doc, source_doc[i:n])/100
        if stringsim > threshold: 
            best_match_list.append(source_doc[i:n])
            best_ratio_list.append(stringsim)
        i += 1
        n += 1

    matches_df = pd.DataFrame(data={"ratio":best_ratio_list, "match":best_match_list, "extracted":dst_doc})
    if len(matches_df) > 0:
        return True, matches_df
    else: 
        return False
    

investigation_idx = 1
dst_doc, source_doc = not_correct_extracted_df.reset_index().text[investigation_idx], not_correct_extracted_df.reset_index().plainpagefulltext[investigation_idx]

bool_val, res_df = find_similiar_sequence(dst_doc=dst_doc, source_doc=source_doc, threshold=0.98)
res_df
# Out:
#        ratio                                              match  \
# 0   0.980736  msterdam . teiraf 27jährig . Herr , ev . , aus...
# 1   0.982487  sterdam . teiraf 27jährig . Herr , ev . , aus ...
# 2   0.984238  terdam . teiraf 27jährig . Herr , ev . , aus e...
# 3   0.985989  erdam . teiraf 27jährig . Herr , ev . , aus er...
# 4   0.987741  rdam . teiraf 27jährig . Herr , ev . , aus ers...
# 5   0.989492  dam . teiraf 27jährig . Herr , ev . , aus erst...
# 6   0.991243  am . teiraf 27jährig . Herr , ev . , aus erste...
# 7   0.992995  m . teiraf 27jährig . Herr , ev . , aus erster...
# 8   0.994746   . teiraf 27jährig . Herr , ev . , aus erster ...
# 9   0.996497  . teiraf 27jährig . Herr , ev . , aus erster r...
# 10  0.998249   teiraf 27jährig . Herr , ev . , aus erster rh...
# 11  0.998249  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 12  0.998249  eiraf 27jährig . Herr , ev . , aus erster rhei...
# 13  0.996497  iraf 27jährig . Herr , ev . , aus erster rhein...
# 14  0.994746  raf 27jährig . Herr , ev . , aus erster rheini...
# 15  0.992995  af 27jährig . Herr , ev . , aus erster rheinis...
# 16  0.991243  f 27jährig . Herr , ev . , aus erster rheinisc...
# 17  0.989492   27jährig . Herr , ev . , aus erster rheinisch...
# 18  0.987741  27jährig . Herr , ev . , aus erster rheinisch ...
# 19  0.985989  7jährig . Herr , ev . , aus erster rheinisch ....
# 20  0.984238  jährig . Herr , ev . , aus erster rheinisch . ...
# 21  0.982487  ährig . Herr , ev . , aus erster rheinisch . a...
# 22  0.980736  hrig . Herr , ev . , aus erster rheinisch . ad...
#
#                                             extracted
# 0   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 1   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 2   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 3   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 4   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 5   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 6   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 7   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 8   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 9   teiraf 27jährig . Herr , ev . , aus erster rhe...
# 10  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 11  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 12  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 13  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 14  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 15  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 16  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 17  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 18  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 19  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 20  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 21  teiraf 27jährig . Herr , ev . , aus erster rhe...
# 22  teiraf 27jährig . Herr , ev . , aus erster rhe...

# %%
def find_similiar_sequence(dst_doc:str, source_doc:str, threshold:float, return_msk:bool) -> bool:
    """Checks if the extracted content is with a certain threshold in the given document. If a 1:1 match is found it directly returns 
    True - if not levenstein distance is used to check if the extracted string is in the document with a certain threshold of stringsimiliarties
    Parameters:
        dst_doc: str - extracted content
        source_doc: str -  original document
        threshold: float - threshold for stringsimiliarities 
        return_msk: bool - parameter True - just return the mask if val is in doc or false the df with the matches and the ratio will be returned
    Returns:
        True if String is in the original document False if it is not in the document within the threshold   
     """
    
    if dst_doc in source_doc: return True
    
    n = len(dst_doc)
    n_src = len(source_doc)
    i = 0

    best_match_list = []
    best_ratio_list = []
    while n < n_src:
        stringsim = fuzz.ratio(dst_doc, source_doc[i:n])/100
        if stringsim > threshold: 
            best_match_list.append(source_doc[i:n])
            best_ratio_list.append(stringsim)
        i += 1
        n += 1

    matches_df = pd.DataFrame(data={"ratio":best_ratio_list, "match":best_match_list, "extracted":dst_doc})
    if len(matches_df) > 0 and not return_msk:
        return True, matches_df
    elif len(matches_df) > 0:
        return True
    else: 
        return False

# %%
import pandas as pd
from rapidfuzz import fuzz

class ExtractionValidator:
    def __init__(self,dst_doc:list, source_doc:list, threshold:float ):
        self.dst_doc = dst_doc
        self.source_doc = source_doc
        self.threshold = threshold

    def find_similiar_sequence(self, dst_doc:str, source_doc:str, threshold:float) -> pd.DataFrame:
        """Checks if the extracted content is with a certain threshold in the given document. If a 1:1 match is found it directly returns 
        True - if not levenstein distance is used to check if the extracted string is in the document with a certain threshold of stringsimiliarties
        Parameters:
            dst_doc: str - extracted content
            source_doc: str -  original document
            threshold: float - threshold for stringsimiliarities 
            return_msk: bool - parameter True - just return the mask if val is in doc or false the df with the matches and the ratio will be returned
        Returns:
            pd.DataFrame containing the potential matches
        """
        
        n = len(dst_doc)
        n_src = len(source_doc)
        i = 0

        best_match_list = []
        best_ratio_list = []
        while n < n_src:
            stringsim = fuzz.ratio(dst_doc, source_doc[i:n])/100
            if stringsim > threshold: 
                best_match_list.append(source_doc[i:n])
                best_ratio_list.append(stringsim)
            i += 1
            n += 1

        matches_df = pd.DataFrame(data={"ratio":best_ratio_list, "match":best_match_list, "extracted":dst_doc})
        
        return matches_df
    
    def is_match(self, dst_doc:str, source_doc:str, threshold:float) -> bool:
        """Checks if a match was found. Check if the text is either one to one in the match or it is within the threshold similiar
        Parameters:
            dst_doc: str - extracted content
            source_doc: str -  original document
            threshold: float - threshold for stringsimiliarities 
            return_msk: bool - parameter True - just return the mask if val is in doc or false the df with the matches and the ratio will be returned
        Returns:
            True if String is in the original document False if it is not in the document within the threshold   
        
        
        """
        if dst_doc in source_doc: return True
        match_df = self.find_similiar_sequence(dst_doc, source_doc, threshold)
        if len(match_df) > 0:
            return True
        else:
            return False
        
    def apply_is_match_on_data(self) -> list[bool]:
        """Applys is_match over all data - Can be used as a mask to filter the values that are not correctly extracted
        
        Parameter:
        None

        Return: 
        List of bool values that determining if the given extracted text was is in (True) the source text within the given threshold or not (False)

        """
        found_match_list:list[bool] = [self.is_match(d, s, self.threshold) for d, s in zip(self.dst_doc, self.source_doc)]
        return found_match_list
    
    def calculate_extraction_accuracy(self) -> tuple:
        """Return tuple with the accuracy of the text extraction"""
        n = len(self.dst_doc)
        match_bool = self.apply_is_match_on_data()
        true_positive = sum(match_bool)
        
        return ("Accuracy", true_positive/n)

# %% [markdown]
# # Ausgabe der extraktion in Dataframe-Format

# %%
print(dat_joined.text.tolist()[0])
print(dat_joined.plainpagefulltext.tolist()[0])

ExtractionValidator(None, None, 0.98).find_similiar_sequence(dst_doc=dat_joined.text.tolist()[0], source_doc=dat_joined.plainpagefulltext.tolist()[0], threshold=0.8)
# Out:
# Suche für meine Tochter , 18 Jahre , Stelle als angeh . Arbeiterin in kathol . Hause bei Familienanschl . in Boun oder Umgegend . Augebote u . A . K . A . 4368 .
# 1 — 92 . R Geicch * 1 RRAR ädchen Schuhmachergeselle # D # eres gesucht . Gehr i vontins grsagr Un . si Sautuus b - futge . Mondorf , Sieglor , Markt 15 . Bäckerlehrling . Suche für meinen 16jähr Sehn bei einem katholischen Meister Stelle als Bäcker lohrling , am liebsten in einer vereinigten Bäckerei und Kon # # torel . Angeb . u . M 357 . Junge von 14 — 16 Jahren vom Leude , der etwas pflügen konn , aufs Land gesucht . # Augeb . unt . G . Sp . 4370 . 120 Lehrlinge # # # d Ostern 1918 in Hand werkslehre unterzubringen . Meldungen mit Nachweis der Befühigung zur Ausbildung von Lehrlingen zu richten an des Städtische Waisen haus , Cöln = Sülz , Stl ; gürtel 41 . relle bämsl . Arbeit gesucht . Bonn , Kurfürstenstr . 62 . Zuverl . , kath . , durchaus ekfohrenes Fräulein als geiaßt . Stütze Frou G . Faßbender , heim b . Cöln , Lindenhof . Propere brave Frau zum Ladenputzen für abends gesucht . Brüdergasse 35 . Für 23jähriges Fräulein aus gut . Bürgerstande , gut angesührt und fleißig , wird zur gründl . Erlernung der Küche und seinen Umgangs sormen Aufnah
# 1   0.807453  e unter J . F . 4367 . Modes . Suche für meine...
# 2   0.813665   unter J . F . 4367 . Modes . Suche für meine ...
# 3   0.819876  unter J . F . 4367 . Modes . Suche für meine T...
# 4   0.826087  nter J . F . 4367 . Modes . Suche für meine To...
# ..       ...                                                ...
# 60  0.826087   Jahre , Stelle als angeh . Arbeiterin in kath...
# 61  0.819876  Jahre , Stelle als angeh . Arbeiterin in katho...
# 62  0.813665  ahre , Stelle als angeh . Arbeiterin in kathol...
# 63  0.807453  hre , Stelle als angeh . Arbeiterin in kathol ...
# 64  0.801242  re , Stelle als angeh . Arbeiterin in kathol ....
#
#                                             extracted
# 0   Suche für meine Tochter , 18 Jahre , Stelle al...
# 1   Suche für meine Tochter , 18 Jahre , Stelle al...
# 2   Suche für meine Tochter , 18 Jahre , Stelle al...
# 3   Suche für meine Tochter , 18 Jahre , Stelle al...
# 4   Suche für meine Tochter , 18 Jahre , Stelle al...
# ..                                                ...
# 60  Suche für meine Tochter , 18 Jahre , Stelle al...
# 61  Suche für meine Tochter , 18 Jahre , Stelle al...
# 62  Suche für meine Tochter , 18 Jahre , Stelle al...
# 63  Suche für meine Tochter , 18 Jahre , Stelle al...
# 64  Suche für meine Tochter , 18 Jahre , Stelle al...
#
# [65 rows x 3 columns]

# %%
dat_joined = pd.read_pickle("dat_joined.pkl")

validation = ExtractionValidator(dst_doc=dat_joined.text.tolist(), source_doc=dat_joined.plainpagefulltext.tolist(), threshold=0.98)
result = validation.calculate_extraction_accuracy()
print(result)
# Out:
# ('Accuracy', 0.9782608695652174)

# %%
len(dat_joined)
# Out:
# 46

# %%
0.022*46
# Out:
# 1.012

# %%
still_not_Correct = dat_joined[msk == False]
still_not_Correct
# Out:
#                                                page_id  \
# 135  2DW55DZZGQDFIT6CBIIFTKK73ARV7ITF-ALTO9398850_D...
# 149  2EZVCCSPNJZR5754MLRQDYIXY65QRKO5-ALTO7690695_D...
# 199  2IIYBCYT6B2SO57MWJ6HQRQZCRAEWU3L-ALTO9548825_D...
# 251  2LB436MW4E74OIMHD2DTFM4ISNWPPBPF-ALTO1934287_D...
# 287  2QINTW3X2TQUT2N7KW6QPCM4INRLQ5D4-ALTO9467138_D...
# 395  373GCHWZ25DT4GNR5J44JCNUHG3GVKQX-ALTO8385016_D...
#
#                                                   text              time  \
# 135  Suchen f . uns . Tochter , Is raelitin , 24 J ...  2025-06-08_20_13
# 149  Herrscheftlüsch eingerrichtetes Haus in Barmen...  2025-06-08_20_13
# 199  Mitte der Her . in sehr gus Verhältnissen , su...  2025-06-08_20_13
# 251  Landwirt , kath . , Junggeselle , 36 Jahre , B...  2025-06-08_20_13
# 287  Eine Gzroßbach , kath , 31 . , Istahlbandarmie...  2025-06-08_20_13
# 395  Glückliche Heirat ! ger Herr , evgl. , großé F...  2025-06-08_20_13
#
#                                      plainpagefulltext
# 135  Gschäffter - Verenl für Bergbau und dussstahlf...
# 149  Bekanntmachung . elsregister ist am in das H #...
# 199  das Handelsregister ist am 14 . September 1920...
# 251  Sonntag , den 16 . September 1917 . Statt beso...
# 287  Der Geutsche Suden . Mitdestes , fast nebelfre...
# 395  An die Stammaktionäre der Howaldtswerke . Auf ...

# %%
find_similiar_sequence(still_not_Correct.text[135], still_not_Correct.plainpagefulltext[135], threshold=0.75, return_msk=False)
# Out:
# False

# %%
6/425
# Out:
# 0.01411764705882353

# %%
import pandas as pd
from scripts.information_extractor_lib import ExtractionValidator

dat_joined = pd.read_pickle("dat_joined.pkl")
dat_joined = dat_joined.head(10)
#validation = ExtractionValidator(dst_doc=dat_joined.text.tolist(), source_doc=dat_joined.plainpagefulltext.tolist(), threshold=0.98)
#result = validation.calculate_extraction_accuracy()
#print(result)

validator = ExtractionValidator(dst_doc=None, source_doc=None, threshold=None)
result = validator.find_similiar_sequence(dst_doc=dat_joined.text[0], source_doc=dat_joined.plainpagefulltext[0], threshold=0.98)
result
# Out:
#       ratio  ...                                          extracted
# 0  0.981366  ...  Suche für meine Tochter , 18 Jahre , Stelle al...
# 1  0.987578  ...  Suche für meine Tochter , 18 Jahre , Stelle al...
# 2  0.993789  ...  Suche für meine Tochter , 18 Jahre , Stelle al...
# 3  1.000000  ...  Suche für meine Tochter , 18 Jahre , Stelle al...
# 4  0.993789  ...  Suche für meine Tochter , 18 Jahre , Stelle al...
# 5  0.987578  ...  Suche für meine Tochter , 18 Jahre , Stelle al...
# 6  0.981366  ...  Suche für meine Tochter , 18 Jahre , Stelle al...
#
# [7 rows x 3 columns]

# %%
from scripts.information_extractor_lib import InformationExtractor
from scripts.config_file import configs, generation_config
import pandas as pd
from full_workflow_config import fw_config

dat_joined_complete = pd.read_pickle("dat_joined.pkl")

dat_joined = dat_joined_complete.head(5)

ocr_corrector = InformationExtractor(df=dat_joined, page_id_colname="page_id", text_colname="text", output_filename="ocr_corrected_df.csv")
#Set the configs for the task to perform
ocr_corrector.prompt = fw_config["CORRECTION_PROMPT"]
ocr_corrector.model_name = fw_config["model_name"]
data_corrected = ocr_corrector.extract_data_loop(5)


word_completion = InformationExtractor(df=data_corrected, page_id_colname="page_id", text_colname="text", output_filename="ocr_corrected_df.csv")

word_completion.prompt = fw_config["COMPLETION_PROMPT"]
word_completion.model_name = fw_config["model_name"]
data_word_completed = word_completion.extract_data_loop(5)


data_word_completed.columns = ['page_id_completed', 'text_completed', 'time_completed']
merged_df = pd.concat([data_corrected, data_word_completed], axis = 1)
merged_df = merged_df.filter(["text", "text_completed"])
print(merged_df)
merged_df.to_csv("merged_df_100.csv")
# Out:
#                                                 text  \
# 0  Suche für meine Tochter, 18 Jahre, Stelle als ...
# 1  Heirats-Gesuche Bei mon aie Gerdprenderch nung...
# 2  Junger Mann, 22 Jahre, kath., sucht aufrichtig...
# 3  Zwei junge Herren, 1921 Jahre, suchen die Beka...
# 4  Teilnahme nach Brückner. Gewissenhafter deutsc...
#
#                                       text_completed
# 0  Suche für meine Tochter, 18 Jahre, Stelle als ...
# 1  Heirats-Gesuche Bei mon aie Gerdprenderch Rech...
# 2  Junger Mann, 22 Jahre, katholisch, sucht aufri...
# 3  Zwei junge Herren, 1921 Jahre, suchen die Beka...
# 4  Teilnahme nach Brückner. Gewissenhafter deutsc...

# %%
merged_df
# Out:
#                                                 text  \
# 0  Suche für meine Tochter, 18 Jahre, Stelle als ...
# 1  Heirats-Gesuche Bei mon aie Gerdprenderch nung...
# 2  Junger Mann, 22 Jahre, kath., sucht aufrichtig...
# 3  Zwei junge Herren, 1921 Jahre, suchen die Beka...
# 4  Teilnahme nach Brückner. Gewissenhafter deutsc...
#
#                                       text_completed
# 0  Suche für meine Tochter, 18 Jahre, Stelle als ...
# 1  Heirats-Gesuche Bei mon aie Gerdprenderch Rech...
# 2  Junger Mann, 22 Jahre, katholisch, sucht aufri...
# 3  Zwei junge Herren, 1921 Jahre, suchen die Beka...
# 4  Teilnahme nach Brückner. Gewissenhafter deutsc...

# %% [markdown]
# # Suchen personen für sich selbst oder für Familien angehörige - als annotatiosfrage

# %%
ExtractionValidator(None, None, 0.98).find_similiar_sequence(dst_doc=dat_joined.text[1], source_doc=dat_joined.plainpagefulltext[1], threshold=0.98)
# Out:
#        ratio                                              match  \
# 0   0.981667  . 4340 . “ Heirats - Gesuche Bei mon aie Gerdp...
# 1   0.983333   4340 . “ Heirats - Gesuche Bei mon aie Gerdpr...
# 2   0.985000  4340 . “ Heirats - Gesuche Bei mon aie Gerdpre...
# 3   0.986667  340 . “ Heirats - Gesuche Bei mon aie Gerdpren...
# 4   0.988333  40 . “ Heirats - Gesuche Bei mon aie Gerdprend...
# 5   0.990000  0 . “ Heirats - Gesuche Bei mon aie Gerdprende...
# 6   0.991667   . “ Heirats - Gesuche Bei mon aie Gerdprender...
# 7   0.993333  . “ Heirats - Gesuche Bei mon aie Gerdprenderc...
# 8   0.995000   “ Heirats - Gesuche Bei mon aie Gerdprenderch...
# 9   0.996667  “ Heirats - Gesuche Bei mon aie Gerdprenderch ...
# 10  0.998333   Heirats - Gesuche Bei mon aie Gerdprenderch n...
# 11  1.000000  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 12  0.998333  eirats - Gesuche Bei mon aie Gerdprenderch nun...
# 13  0.996667  irats - Gesuche Bei mon aie Gerdprenderch nung...
# 14  0.995000  rats - Gesuche Bei mon aie Gerdprenderch nunge...
# 15  0.993333  ats - Gesuche Bei mon aie Gerdprenderch nungen...
# 16  0.991667  ts - Gesuche Bei mon aie Gerdprenderch nungen ...
# 17  0.990000  s - Gesuche Bei mon aie Gerdprenderch nungen o...
# 18  0.988333   - Gesuche Bei mon aie Gerdprenderch nungen od...
# 19  0.986667  - Gesuche Bei mon aie Gerdprenderch nungen ode...
# 20  0.985000   Gesuche Bei mon aie Gerdprenderch nungen oder...
# 21  0.983333  Gesuche Bei mon aie Gerdprenderch nungen oder ...
# 22  0.981667  esuche Bei mon aie Gerdprenderch nungen oder d...
#
#                                             extracted
# 0   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 1   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 2   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 3   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 4   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 5   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 6   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 7   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 8   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 9   Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 10  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 11  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 12  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 13  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 14  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 15  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 16  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 17  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 18  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 19  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 20  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 21  Heirats - Gesuche Bei mon aie Gerdprenderch nu...
# 22  Heirats - Gesuche Bei mon aie Gerdprenderch nu...

# %% [markdown]
# # Wie verhindern garbage in garbage out ?  Dropout für nicht kontaktanzeigen oder zu weit extrahierte Textfenster
